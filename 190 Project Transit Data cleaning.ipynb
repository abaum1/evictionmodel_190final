# %%
import pandas as pd
import geopandas as gp
import numpy as np

# %% [markdown]
# ## Muni bus stop data

# %%
path = '/Users/ameliabaum/Desktop/Amelia/Berkeley 2018-2019/EnRes C190/Final Project/'
stops = pd.read_csv('/Users/ameliabaum/Desktop/Amelia/Berkeley 2018-2019/EnRes C190/Final Project/google_transit/stops.txt')
shapes = pd.read_csv('/Users/ameliabaum/Desktop/Amelia/Berkeley 2018-2019/EnRes C190/Final Project/google_transit/shapes.txt')
routes = pd.read_csv('/Users/ameliabaum/Desktop/Amelia/Berkeley 2018-2019/EnRes C190/Final Project/google_transit/routes.txt')
stop_times = pd.read_csv('/Users/ameliabaum/Desktop/Amelia/Berkeley 2018-2019/EnRes C190/Final Project/google_transit/stop_times.txt')
trips = pd.read_csv('/Users/ameliabaum/Desktop/Amelia/Berkeley 2018-2019/EnRes C190/Final Project/google_transit/trips.txt')

# %%
trips_and_shapes = trips.merge(shapes, how='inner', left_on='shape_id', right_on='shape_id')
trips_shapes_routes = trips_and_shapes.merge(routes, how='left', left_on='route_id', right_on='route_id')
trips_shapes_routes.head()
# Out:
#    route_id  service_id  trip_id        trip_headsign  direction_id  block_id  \
# 0     13392           1  8318856  Geary + 33rd Avenue             0       122
# 1     13392           1  8318856  Geary + 33rd Avenue             0       122
# 2     13392           1  8318856  Geary + 33rd Avenue             0       122
# 3     13392           1  8318856  Geary + 33rd Avenue             0       122
# 4     13392           1  8318856  Geary + 33rd Avenue             0       122
#
#    shape_id  shape_pt_lon  shape_pt_lat  shape_pt_sequence  \
# 0    159274   -122.396968     37.795436                  1
# 1    159274   -122.396784     37.795471                  2
# 2    159274   -122.396598     37.794593                  3
# 3    159274   -122.397809     37.794439                  4
# 4    159274   -122.398983     37.794289                  5
#
#    shape_dist_traveled
# 0                    0
# 1                   17
# 2                  116
# 3                  224
# ...

# %%
# trips_shapes_routes.head().to_csv("trips_shapes_routes.csv") #need to try and figure out which ones are frequent

# %% [markdown]
# ## Commutter Shuttle Program Data

# %%
commuter_program_shuttles = gp.read_file(path+'MTA.speedbumps/geo_export_e2840cb2-6482-4a2f-bd56-0878a2cbccf3.shp')
commuter_program_shuttles
# Out:
#           cnn date_creat time_creat created_us     from_st date_last_  \
# 0  10792000.0       None       None       None     16TH ST       None
# 1   3760101.0       None       None       None  HUDSON AVE       None
# 2   2958000.0       None       None       None  HUDSON AVE       None
# 3  10970201.0       None       None       None  HUDSON AVE       None
# 4   7002000.0       None       None       None     PARK ST       None
#
#   time_last_ last_edite date_mtab_ time_mtab_ mtab_motio mtab_reso_  objectid  \
# 0       None       None       None       None       None       None      48.0
# 1       None       None       None       None       None       None      11.0
# 2       None       None       None       None       None       None       8.0
# 3       None       None       None       None       None       None      49.0
# 4       None       None       None       None       None       None      32.0
#
#   status      streetname            to_st workorder  \
# ...
