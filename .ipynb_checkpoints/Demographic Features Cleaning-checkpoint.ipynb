# %%
import pandas as pd
import geopandas as gp
import numpy as np

# %%
blkgp_shapefiles = gp.read_file("/Users/ameliabaum/Desktop/Amelia/Berkeley 2018-2019/EnRes C190/evictionmodel_190final/cb_2017_06_bg_500k/cb_2017_06_bg_500k.shp")
blkgp_shapefiles.dtypes
# Out:
# STATEFP     object
# COUNTYFP    object
# TRACTCE     object
# BLKGRPCE    object
# AFFGEOID    object
# GEOID       object
# NAME        object
# LSAD        object
# ALAND        int64
# AWATER       int64
# geometry    object
# dtype: object

# %%
sf_blks = blkgp_shapefiles[blkgp_shapefiles["COUNTYFP"] == '075']
sf_blks.plot()
